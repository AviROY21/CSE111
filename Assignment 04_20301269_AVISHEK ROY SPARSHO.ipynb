# %%
# Task 01
firstValue = int(input())
operator = input()
secondValue = int(input())

print('Lets Calculate!')
print(f'ValueOne: {firstValue} ')
print(f' Operator: {operator}')
print(f'ValueTwo: {secondValue}')

class Calculator:
    def addition(self,ValueOne,ValueTwo):
            print('Result:',ValueOne + ValueTwo)
    def subtraction(self,ValueOne,ValueTwo ):
        print('Result:', ValueOne - ValueTwo)
    def multiply(self,ValueOne, ValueTwo):
            print('Result:',ValueOne*ValueTwo)
    def divide(self,ValueOne,ValueTwo):
            print('Result:',ValueOne/ValueTwo)

cal1 = Calculator()
Result=(firstValue,operator,secondValue)
if operator == ' + ' :
    cal1.addition(firstValue,secondValue)
if  operator == '- ' :
    cal1.subtraction(firstValue,secondValue)
if  operator == '* ' :
    cal1.multiply(firstValue,secondValue)
if  operator == '/ '  :
    cal1.divide(firstValue,secondValue)
# Out:
# 1
# +
# 2
# Lets Calculate!
# ValueOne: 1
#  Operator: +
# ValueTwo: 2

# %%
#Task - 02

class Customer:
    def __init__(self,name1):
        self.name1 = name1

    def greet(self,name2 = None):
        if name2 == None:
            print(f"Hello!")
        else:
            print(f"Hello {name2}!")
    def purchase(self,*item):
        print(f"Sam, you purchased {len(item)} item(s):")
        print(f"David, you purchased {len(item)} item(s):")
        for i in item:
            print(i)

customer_1 = Customer("Sam")
customer_1.greet()
customer_1.purchase("chips", "chocolate", "orange juice")
print("----------------------------")
customer_2 = Customer("David")
customer_2.greet("David")
customer_2.purchase("orange juice")
# Out:
# Hello!
# Sam, you purchased 3 item(s):
# David, you purchased 3 item(s):
# chips
# chocolate
# orange juice
# ----------------------------
# Hello David!
# Sam, you purchased 1 item(s):
# David, you purchased 1 item(s):
# orange juice

# %%
#Task-03
class Panda:
    def __init__(self,name,age,gender):
        self.name=name
        self.gender=gender
        self.age =age

    def Sleep(self,Time=None):
        if Time == None:
            return f'{self.name}’s duration is unknown thus should have only bamboo leaves'
        elif  Time >= 3 and Time <=5:
            return f'{self.name} sleeps {Time} hours daily and should have Mixed Veggies'
        elif  Time >= 6 and Time <= 8:
            return f'{self.name} sleeps {Time} hours daily and should have Eggplant & Tofu'
        elif  Time >= 9 and Time <= 11:
            return f'{self.name} sleeps {Time} hours daily and should have Broccoli Chicken'

panda1 = Panda('Kunfu', 'Male', 5)

panda2=Panda('Pan Pan','Female',3)
panda3=Panda('Ming Ming' ,'Female',8)

print("{} is a {} Panda Bear who is {} years old".format(panda1.name,panda1.gender,panda1.age))
print("{} is a {} Panda Bear who is {} years old".format(panda2.name,panda2.gender,panda2.age))
print("{} is a {} Panda Bear who is {} years old".format(panda3.name,panda3.gender,panda3.age))

print()

print(panda2.Sleep(10))
print(panda1.Sleep(4))
print(panda3.Sleep())
# Out:
# Kunfu is a 5 Panda Bear who is Male years old
# Pan Pan is a 3 Panda Bear who is Female years old
# Ming Ming is a 8 Panda Bear who is Female years old
#
# Pan Pan sleeps 10 hours daily and should have Broccoli Chicken
# Kunfu sleeps 4 hours daily and should have Mixed Veggies
# Ming Ming’s duration is unknown thus should have only bamboo leaves

# %%
# Task- 04
class Cat:
    def __init__(self,colour = 'White', condition = 'sitting'):
        self.colour = colour
        self.condition = condition
    def printCat(self):
        print(f'{self.colour} cat is { self.condition}')
    def changeColor(self,colour):
        self.colour = colour

c1 = Cat()
c2 = Cat('Black')
c3 = Cat('Brown', 'jumping')
c4 = Cat('Red', 'purring')
c1.printCat()
c2.printCat()
c3.printCat()
c4.printCat()
c1.changeColor('Blue')
c3.changeColor('Purple')
c1.printCat()
c3.printCat()
# Out:
# White cat is sitting
# Black cat is sitting
# Brown cat is jumping
# Red cat is purring
# Blue cat is sitting
# Purple cat is jumping

# %%
#TAsk-5
class Vehicle:
    def __int__(self,x,y):
        self.x=0
        self.y=0
    def moveUp(self):
        self.y=self.y + 1
    def moveDown(self):
        self.y=self.y - 1
    def moveRight(self):
        self.x=self.x + 1
    def moveLeft(self):
        self.x=self.x - 1
    def print_position(self):
        print((self.x, self.y))

car = Vehicle()
car.print_position()
car.moveUp()
car.print_position()
car.moveLeft()
car.print_position()
car.moveDown()
car.print_position()
car.moveRight()

# %%
#Task-6
class Programmer:
    def __init__(self,name,prolan,exp):
        self.name = name
        self.prolan =prolan
        self.exp =exp

    def addExp(self,exp):
        print("Updating experience of Jon Snow")
        self.exp = exp + self.exp
    def printDetails(self):
        print('Horray! A new programmer is born')
        print(f'Name: {self.name}')
        print(f'Language: {self.prolan}')
        print(f'Experience: {self.exp} years.')
p1 = Programmer("Ethen Hunt", "Java", 10)
p1.printDetails()
print('------------------------')
p2 = Programmer("James Bond", "C++", 7)
p2.printDetails()
print('------------------------')
p3 = Programmer("Jon Snow", "Python", 4)
p3.printDetails()
p3.addExp(5)
p3.printDetails()
# Out:
# Horray! A new programmer is born
# Name: Ethen Hunt
# Language: Java
# Experience: 10 years.
# ------------------------
# Horray! A new programmer is born
# Name: James Bond
# Language: C++
# Experience: 7 years.
# ------------------------
# Horray! A new programmer is born
# Name: Jon Snow
# Language: Python
# Experience: 4 years.
# Updating experience of Jon Snow
# Horray! A new programmer is born
# Name: Jon Snow
# Language: Python
# Experience: 9 years.

# %%
# Task-7
class Student:
    def __init__(self,name,ID,Dep= "CSE"):
        self.name = name
        self.ID = ID
        self.dep = Dep
    def dailyEffort(self,hour):
        self.hour = hour
    def printDetails(self):
        print(f'Name: {self.name}')
        print(f'ID: {self.ID}')
        print(f'Department: {self.dep}')
        print(f'Daily Effort: {self.hour} hour(s)')
        if self.hour <=2:
            print('Suggestion: Should give more effort!')
        elif self.hour <=4:
            print('Suggestion: Keep up the good work!')
        else:
            print('Suggestion: Excellent! Now motivate others.')

harry = Student('Harry Potter', 123)
harry.dailyEffort(3)
harry.printDetails()
print('-------------------')
john = Student("John Wick", 456, "BBA")
john.dailyEffort(2)
john.printDetails()
print('-------------------')
naruto = Student("Naruto Uzumaki", 777, "Ninja")
naruto.dailyEffort(6)
naruto.printDetails()

# %%
# Task-8
class Patient:
    def __init__(self ,name ,age):
        self.name =name
        self.age =age
    def add_Symptom(self,*multiple):
        self.multiple = multiple
    def printPatientDetail(self):
        print(f'Name: {self.name}')
        print(f'Age: {self.age}')
        print(f'Symtomps: {self.multiple}')

p1 = Patient('Thomas', 23)
p1.add_Symptom('Headache')
p2 = Patient('Carol', 20)
p2.add_Symptom('Vomiting', 'Coughing')
p3 = Patient('Mike', 25)
p3.add_Symptom('Fever', 'Headache', 'Coughing')
print("=======================")
p1.printPatientDetail()
print("=======================")
p2.printPatientDetail()
print("=======================")
p3.printPatientDetail()
print("=======================")
# Out:
# ...
# Name: Thomas
# Age: 23
# Symtomps: ('Headache',)
# ...
# Name: Carol
# Age: 20
# Symtomps: ('Vomiting', 'Coughing')
# ...
# Name: Mike
# Age: 25
# Symtomps: ('Fever', 'Headache', 'Coughing')
# ...

# %%
# Task-9
class Avengers:
    def __init__(self, name, age):
        self.name = name
        self.age = age
    def super_powers(self, *multiple):
        self.multiple = multiple
    def printAvengersDetail(self):
        print(f'Name: {self.name}')
        print(f'Partner: {self.age}')
        print(f'Super powers: {self.multiple}')
a1 = Avengers('Captain America','Bucky Barnes')
a1.super_powers('Stamina','Slowed ageing')
a2 = Avengers('Doctor Strange','Ancient One')
a2.super_powers('Mastery of magic')
a3 = Avengers('Iron Man','War Machine')
a3.super_powers('Genius level intellect', 'Scientist ')
print("=======================")
a1.printAvengersDetail()
print("=======================")
a2.printAvengersDetail()
print("=======================")
a3.printAvengersDetail()
print("=======================")
# Out:
# ...
# Name: Captain America
# Partner: Bucky Barnes
# Super powers: ('Stamina', 'Slowed ageing')
# ...
# Name: Doctor Strange
# Partner: Ancient One
# Super powers: ('Mastery of magic',)
# ...
# Name: Iron Man
# Partner: War Machine
# Super powers: ('Genius level intellect', 'Scientist ')
# ...

# %%
#Task-10
class Shinobi:
    def __init__(self, name, rank, mission=0):
        self.name = name
        self.rank = rank
        self.mission = mission
    def changeRank(self, rank):
        self.rank = rank
    def calSalary(self, mission):
        self.mission = mission
        a= self.mission
    def printInfo(self):
        print(f'Name: {self.name}')
        print(f'Rank: {self.rank}')
        print(f'Number of mission: {self.mission}')
        
        if self.rank =='Genin':
            salary = self.mission*50
        
        if self.rank =='Chunin':
            salary = self.mission*100
        
        else:
            salary = self.mission*500
        print(f'Salary: {salary}')
        
naruto = Shinobi("Naruto", "Genin")
naruto.calSalary(5)
naruto.printInfo()
print('==================')
shikamaru = Shinobi('Shikamaru', "Genin")
shikamaru.printInfo()
shikamaru.changeRank("Chunin")
shikamaru.calSalary(10)
shikamaru.printInfo()
print('==================')
neiji = Shinobi("Neiji", "Jonin")
neiji.calSalary(5)
neiji.printInfo()
# Out:
# Name: Naruto
# Rank: Genin
# Number of mission: 5
# Salary: 2500
# ...
# Name: Shikamaru
# Rank: Genin
# Number of mission: 0
# Salary: 0
# Name: Shikamaru
# Rank: Chunin
# Number of mission: 10
# Salary: 1000
# ...
# Name: Neiji
# Rank: Jonin
# Number of mission: 5
# Salary: 2500
